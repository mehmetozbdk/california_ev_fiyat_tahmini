# %%
# Mehmet ÖZBUDAK - 19110131053

# kütüphaneler

# pandas 
# Veri işlemesi ve analizi için Python programlama dilinde yazılmış olan bir kütüphanedir. 
# Temel olarak zaman etiketli serileri ve sayısal tabloları işlemek için bir 
# veri yapısı oluşturur ve yapıyı çeşitli işlemler ile işler-analiz eder.

# numpy
# çok büyük ölçekteki matematiksel-bilimsel hesaplamaları kolay, hızlı ve esnek bir şekilde gerçekleştirmemizi sağlayan
# çözümleri içeren kütüphanedir.

#seaborn
# İstatiksel hesaplamalara yeni bir anlam ve farklı bir bakış açısı kazandırmak için
# kullanılan oldukça efektif ve bir o kadar popüler olan bir veri görselleştirme kütüphanesidir. 

import pandas as pd;
import numpy as np;
import seaborn as sbn;
import matplotlib.pyplot as plt
sbn.set_style('darkgrid')

# %%
# veriyi yükleme
data = pd.read_csv('housing.csv');

# %%
# kolon isimlerini inceleme
data.shape
# Out:
# (20640, 10)

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
# kolon isimlerini inceleme(isimlendirme)
data.columns = ["boylam","enlem","ort_ev_yasi","toplam_oda",
                "toplam_yatak_odasi","nufüs","hane_sayisi","ort_gelir","ev_fiyati","okyanusa_yakinlik"];

# %%
# verinin ilk 5 satırı
data.head()
# Out:
#    boylam  enlem  ort_ev_yasi  toplam_oda  toplam_yatak_odasi   nufüs  \
# 0 -122.23  37.88         41.0       880.0               129.0   322.0
# 1 -122.22  37.86         21.0      7099.0              1106.0  2401.0
# 2 -122.24  37.85         52.0      1467.0               190.0   496.0
# 3 -122.25  37.85         52.0      1274.0               235.0   558.0
# 4 -122.25  37.85         52.0      1627.0               280.0   565.0
#
#    hane_sayisi  ort_gelir  ev_fiyati okyanusa_yakinlik
# 0        126.0     8.3252   452600.0          NEAR BAY
# 1       1138.0     8.3014   358500.0          NEAR BAY
# 2        177.0     7.2574   352100.0          NEAR BAY
# 3        219.0     5.6431   341300.0          NEAR BAY
# 4        259.0     3.8462   342200.0          NEAR BAY

# %%
data.describe()
# Out:
#              boylam         enlem   ort_ev_yasi    toplam_oda  \
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean    -119.569704     35.631861     28.639486   2635.763081
# std        2.003532      2.135952     12.585558   2181.615252
# min     -124.350000     32.540000      1.000000      2.000000
# 25%     -121.800000     33.930000     18.000000   1447.750000
# 50%     -118.490000     34.260000     29.000000   2127.000000
# 75%     -118.010000     37.710000     37.000000   3148.000000
# max     -114.310000     41.950000     52.000000  39320.000000
#
#        toplam_yatak_odasi         nufüs   hane_sayisi     ort_gelir  \
# count        20433.000000  20640.000000  20640.000000  20640.000000
# mean           537.870553   1425.476744    499.539680      3.870671
# std            421.385070   1132.462122    382.329753      1.899822
# min              1.000000      3.000000      1.000000      0.499900
# ...

# %%
# nan deger kontrolu
data.isna().sum()
# Out:
# boylam                  0
# enlem                   0
# ort_ev_yasi             0
# toplam_oda              0
# toplam_yatak_odasi    207
# nufüs                   0
# hane_sayisi             0
# ort_gelir               0
# ev_fiyati               0
# okyanusa_yakinlik       0
# dtype: int64

# %%
# verinin miktarı
data.shape
# Out:
# (20640, 10)

# %%
# veririnin ort ile doldurulması
data["toplam_yatak_odasi"].fillna((data["toplam_yatak_odasi"].mean()),inplace=True)

# inplace veride geçerli olsun mu demek mean() ort hesaplamamk için kullanıldı

# %%
#Veri kümemizin farklı özellikleri şunlardır:

# Boylam
# Enlem
# Evin Medyan Yaşı
# Bloktaki Toplam Oda
# Blokta Toplam Yatak Odası
# bloğun nüfusu
# Hane Sayısı
# Okyanus Yakınlığı
# Ev Başına Oda Sayısı
# Ev Başına Yatak Odası Sayısı
# Hane başına düşen kişi sayısı

# %%
# tekrar nan kontrolu
data.isna().sum()
# Out:
# boylam                0
# enlem                 0
# ort_ev_yasi           0
# toplam_oda            0
# toplam_yatak_odasi    0
# nufüs                 0
# hane_sayisi           0
# ort_gelir             0
# ev_fiyati             0
# okyanusa_yakinlik     0
# dtype: int64

# %%
# Ne tür verilerle uğraştığınızı anlamanın 
# bir başka hızlı yolu da her sayısal nitelik için bir histogram çizmektir
# histogramlar
data.hist(bins= 30, figsize=(10,12))
plt.show()

# %%
# Veri goruntuleme 
plt.figure(figsize=(18,10))
plt.scatter(data['enlem'],data['boylam'],c= data['nufüs'], cmap='cool', alpha = 0.8)
plt.colorbar().set_label("nufüs")
plt.title('Nüfus Büyüklüğü')
plt.xlabel('Enlem')
plt.ylabel('Boylam')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(data.ev_fiyati, bins = 45, ec = 'black', color = '#f88f01')
plt.xlabel('Bir bloktaki Evlerin Medyan Fiyatı $', fontsize=16)
plt.ylabel('Ev Sayısı', fontsize = 16)
plt.title('Bir Blokta Konut Ortalama Fiyatının Ortalama Dağılımı', fontsize=16)
plt.axvline(data['ev_fiyati'].mean(), color='#21209c', linestyle='dashed', linewidth=3, label='Bir Blokta Evin Ortalama Fiyatı')
plt.show()
plt.style.use('dark_background')

# %%
plt.figure(figsize=(10, 6))
sbn.distplot(data.ev_fiyati, bins = 45, color = '#f88f01', hist = True)
plt.style.use('dark_background')
plt.xlabel('Bir bloktaki Evlerin Medyan Fiyatı $ cinsinden', fontsize=16)
plt.ylabel('Ev Sayısı', fontsize=16)
plt.title('Bir Blokta Konut Ortalama Fiyatının Ortalama Dağılımı', fontsize=16)
plt.show()
# Out:
# C:\Users\ozbdk\AppData\Local\Temp\ipykernel_13980\4017290612.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(data.ev_fiyati, bins = 45, color = '#f88f01', hist = True)

# %%
sbn.lmplot(x='ev_fiyati', y='toplam_oda',data = data)

# %%
#label encoder yüklenmesi
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder();

# okyanusa_yakinlik ta string olan değişkenleri LabelEncoder yaparak int dönüştürdük
data["okyanusa_yakinlik"] = le.fit_transform(data["okyanusa_yakinlik"])

# %%
data.head()
# Out:
#    boylam  enlem  ort_ev_yasi  toplam_oda  toplam_yatak_odasi   nufüs  \
# 0 -122.23  37.88         41.0       880.0               129.0   322.0
# 1 -122.22  37.86         21.0      7099.0              1106.0  2401.0
# 2 -122.24  37.85         52.0      1467.0               190.0   496.0
# 3 -122.25  37.85         52.0      1274.0               235.0   558.0
# 4 -122.25  37.85         52.0      1627.0               280.0   565.0
#
#    hane_sayisi  ort_gelir  ev_fiyati  okyanusa_yakinlik
# 0        126.0     8.3252   452600.0                  3
# 1       1138.0     8.3014   358500.0                  3
# 2        177.0     7.2574   352100.0                  3
# 3        219.0     5.6431   341300.0                  3
# 4        259.0     3.8462   342200.0                  3

# %%
# heat map

# annot = açıklama
cor = data.corr()

sbn.heatmap(cor,annot=True)

# boylan ve enlem diğer columnlarla işilkisi - oldugu için etkisiz eleman
# Out:
# <AxesSubplot: >

# %%
# veriyi describe et

data.info
# Out:
# <bound method DataFrame.info of        boylam  enlem  ort_ev_yasi  toplam_oda  toplam_yatak_odasi   nufüs  \
# 0     -122.23  37.88         41.0       880.0               129.0   322.0
# 1     -122.22  37.86         21.0      7099.0              1106.0  2401.0
# 2     -122.24  37.85         52.0      1467.0               190.0   496.0
# 3     -122.25  37.85         52.0      1274.0               235.0   558.0
# 4     -122.25  37.85         52.0      1627.0               280.0   565.0
# ...       ...    ...          ...         ...                 ...     ...
# 20635 -121.09  39.48         25.0      1665.0               374.0   845.0
# 20636 -121.21  39.49         18.0       697.0               150.0   356.0
# 20637 -121.22  39.43         17.0      2254.0               485.0  1007.0
# 20638 -121.32  39.43         18.0      1860.0               409.0   741.0
# 20639 -121.24  39.37         16.0      2785.0               616.0  1387.0
#
# ...

# %%
# x ve y #verileri x y diye ayır ve kontrol et
# X = bağımsız değişkenim , y= bağımlı değşken
# axis column olarak al 

# ev fiyatları hariç tüm columnları alacak
x = data.drop(["ev_fiyati"],axis=1)

# sadece ev fiyatları alacak
y = data.iloc[:,8]

# %%
x.head()
# Out:
#    boylam  enlem  ort_ev_yasi  toplam_oda  toplam_yatak_odasi   nufüs  \
# 0 -122.23  37.88         41.0       880.0               129.0   322.0
# 1 -122.22  37.86         21.0      7099.0              1106.0  2401.0
# 2 -122.24  37.85         52.0      1467.0               190.0   496.0
# 3 -122.25  37.85         52.0      1274.0               235.0   558.0
# 4 -122.25  37.85         52.0      1627.0               280.0   565.0
#
#    hane_sayisi  ort_gelir  okyanusa_yakinlik
# 0        126.0     8.3252                  3
# 1       1138.0     8.3014                  3
# 2        177.0     7.2574                  3
# 3        219.0     5.6431                  3
# 4        259.0     3.8462                  3

# %%
y.head()
# Out:
# 0    452600.0
# 1    358500.0
# 2    352100.0
# 3    341300.0
# 4    342200.0
# Name: ev_fiyati, dtype: float64

# %%
#train test split

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.20, shuffle = True,random_state=1200)

veri_kesitleri = {"x_train"  : x_train
                  ,"x_test"  : x_test
                  ,"y_train" : y_train
                  ,"y_test"  : y_test}

for i in veri_kesitleri:
    print(f"{i}: satır sayısı {veri_kesitleri.get(i).shape[0]}")
# Out:
# x_train: satır sayısı 16512
# x_test: satır sayısı 4128
# y_train: satır sayısı 16512
# y_test: satır sayısı 4128

# %%
# data setimde bazı buyuk degerler var bunlar tahmini olumssuz etkileyebiliri
# bunun için data seti degerlerimi sıkıştırıdım 

from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
x_train = ss.fit_transform(x_train)
x_test = ss.fit_transform(x_test)

# %%
#burada bütün modelleri ımport ediyoruz.

from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis


#burada modelleri bir listenin içerisine alıp parametreleri ile beraber tanımlıyoruz.
models = []
models.append(('LinnearRegresyon Regression', LinearRegression()))
models.append(('Logistic Regression', LogisticRegression()))
models.append(('Naive Bayes', GaussianNB()))
models.append(('Decision Tree (CART)',DecisionTreeClassifier())) 
models.append(('K-NN', KNeighborsClassifier()))


#burada bir döngü vasıtasıyla tek tek bütün modelleri deneyerek sonuçları karşılaştırıyoruz. 
for name, model in models:
    model = model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    from sklearn.metrics import r2_score

    print("%s -> ACC: %%%.2f" % (name,r2_score(y_pred,y_test)*100))
# Out:
# LinnearRegresyon Regression -> ACC: %46.59
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [27], line 22
#      20 #burada bir döngü vasıtasıyla tek tek bütün modelleri deneyerek sonuçları karşılaştırıyoruz.
#      21 for name, model in models:
# ---> 22     model = model.fit(x_train, y_train)
#      23     y_pred = model.predict(x_test)
#      24     from sklearn.metrics import r2_score
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:1233, in LogisticRegression.fit(self, X, y, sample_weight)
#    1230 else:
#    1231     n_threads = 1
# -> 1233 fold_coefs_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose, prefer=prefer)(
#    1234     path_func(
#    1235         X,
#    1236         y,
#    1237         pos_class=class_,
#    1238         Cs=[C_],
#    1239         l1_ratio=self.l1_ratio,
# ...

# %%
#random forest ile eğit en iyi sonuç veren modelim

from sklearn.ensemble import RandomForestRegressor

rfr_model = RandomForestRegressor()
rfr_model.fit(x_train,y_train)

# random forest ile tahmin al ve doğruluğunu bas
precision_rfr = rfr_model.predict(x_test)
print(r2_score(precision_rfr,y_test))

# %%
from sklearn import metrics

# Regresyon analizimizi değerlendirebileceğimiz fonksiyonum

def scoreResults(model, x_train, x_test, y_train, y_test):

    y_train_predict = model.predict(x_train)
    y_test_predict = model.predict(x_test)

    r2_train = metrics.r2_score(y_train, y_train_predict)
    r2_test = metrics.r2_score(y_test, y_test_predict)

    mse_train = metrics.mean_squared_error(y_train, y_train_predict)
    mse_test = metrics.mean_squared_error(y_test, y_test_predict)

    return [r2_train, r2_test, 
            ,mse_test]

# %%
# Klasik yöntem ile bölerek oluşturulan regresyon modelinin sonuçlarını kurduğumuz fonksiyon üzerinden öğrenelim.

result_lr = scoreResults(model = lr_model, x_train = x_train, x_test = x_test, y_train = y_train, y_test = y_test)

print(f"Train R2 Score: {result_lr[0]:.4f} MSE: {result_lr[2]:.4f}")
print(f"Test R2 Score: {result_lr[1]:9.4f} MSE: {result_lr[3]:.4f}")

# %%
# cross validation RandomForestRegressor
from sklearn.datasets import load_wine
from sklearn.model_selection import KFold, train_test_split, cross_val_predict,cross_val_score

k = 5

k_folds = KFold(n_splits = k, random_state = 49, shuffle = True)

scores = cross_val_score(rfr_model, X, y, cv = k_folds)

# 5 veri setinin scor degerleri
for i in scores:
    print("Cross Validation Skoru:", i)

    
print("\nOrt CV Skoru: ", scores.mean())
print("Ortalamada Kullanılan CV Puanı Sayısı: ", len(scores))

# %%
# Korelasyon matrisinin hesaplanması
sürekliStunlar  = ["boylam","enlem","ort_ev_yasi","toplam_oda",
                "toplam_yatak_odasi","nufüs","hane_sayisi","ort_gelir","ev_fiyati"]

# Korelasyon matrisinin oluşturulması
korelasyonData = data[sürekliStunlar].corr()

korelasyonData
# Out:
#                       boylam     enlem  ort_ev_yasi  toplam_oda  \
# boylam              1.000000 -0.924664    -0.108197    0.044568
# enlem              -0.924664  1.000000     0.011173   -0.036100
# ort_ev_yasi        -0.108197  0.011173     1.000000   -0.361262
# toplam_oda          0.044568 -0.036100    -0.361262    1.000000
# toplam_yatak_odasi  0.069260 -0.066658    -0.318998    0.927253
# nufüs               0.099773 -0.108785    -0.296244    0.857126
# hane_sayisi         0.055310 -0.071035    -0.302916    0.918484
# ort_gelir          -0.015176 -0.079809    -0.119034    0.198050
# ev_fiyati          -0.045967 -0.144160     0.105623    0.134153
#
#                     toplam_yatak_odasi     nufüs  hane_sayisi  ort_gelir  \
# boylam                        0.069260  0.099773     0.055310  -0.015176
# enlem                        -0.066658 -0.108785    -0.071035  -0.079809
# ort_ev_yasi                  -0.318998 -0.296244    -0.302916  -0.119034
# ...

# %%
# Yalnızca Hedef Değişken ile mutlak korelasyonun > 0,5 olduğu sütunları filtreleme

# biz burda 0.5 yakın degeleri aldık
# herhangi bir değişken seçilmezse 0,5 eşiğini azaltın

korelasyonData['ev_fiyati'][abs(korelasyonData['ev_fiyati']) > 0.1 ]
# Out:
# enlem         -0.144160
# ort_ev_yasi    0.105623
# toplam_oda     0.134153
# ort_gelir      0.688075
# ev_fiyati      1.000000
# Name: ev_fiyati, dtype: float64
